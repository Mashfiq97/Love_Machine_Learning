# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("LogisticRegression.csv")
df.head(5)
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age, df.bought_insurance, marker="+", color="red")

# %% [markdown]
# 0 line: do not bought the insurance;
# 1 line: bought the insurance

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
# first paramter multidimensional
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, test_size=0.1)

# %%
X_test
# Out:
#     age
# 10   18
# 11   28
# 19   18

# %%
X_train
# Out:
#     age
# 18   19
# 4    46
# 22   40
# 8    62
# 0    22
# 9    61
# 14   49
# 26   23
# 20   21
# 3    52
# 13   29
# 17   58
# 21   26
# 12   27
# 24   50
# 1    25
# 23   45
# 15   55
# 7    60
# 6    55
# 5    56
# 25   54
# 2    47
# 16   25

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0])

# %%
y_test
# Out:
# 10    0
# 11    0
# 19    0
# Name: bought_insurance, dtype: int64

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
model.predict_proba(X_test)
# Out:
# array([[0.92392989, 0.07607011],
#        [0.77595843, 0.22404157],
#        [0.92392989, 0.07607011]])

# %% [markdown]
# 1) First value is the probability of not buying the insurance
