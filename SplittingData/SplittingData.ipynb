# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
df= pd.read_csv("SplitData.csv")
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Finding the information between independent and dependent variables

# %% [markdown]
# ### Car Mileage Vs Sell Price

# %%
plt.scatter(df['Mileage'], df['Sell Price($)']) #linear Relation

# %% [markdown]
# ### Car Age Vs Sell Price

# %%
plt.scatter(df['Age(yrs)'], df['Sell Price($)']) #linear Relation

# %%
X = df[['Mileage', 'Age(yrs)']] 
Y = df['Sell Price($)']

# %%
X
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
Y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### random selection automatice

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2)

# %%
len(X) # total datasize
# Out:
# 20

# %%
len(X_train)
# Out:
# 16

# %%
len(X_test)
# Out:
# 4

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test)
# Out:
# array([23174.06950636, 25859.41522018, 22682.99650456, 14181.88250229])

# %% [markdown]
# ### Actual values

# %%
Y_test
# Out:
# 17    19700
# 12    26000
# 9     22000
# 8     12000
# Name: Sell Price($), dtype: int64
